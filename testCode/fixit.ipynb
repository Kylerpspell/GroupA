# %%
with open('fix.txt', 'r') as f:
	for line in f:
		f = line.strip()
		g = f.replace(' ', '_')
		g += ','
		print(g.upper())
# Out:
# ACCOUNTING,
# ADVERTISING,
# AFRICAN_AMERICAN_STUDIES,
# ANTHROPOLOGY,
# ART_EDUCATION,
# ART_HISTORY,
# ART_STUDIO,
# ATHLETIC_TRAINING,
# BIOCHEMISTRY_AND_MOLECULAR_BIOLOGY,
# BIOLOGICAL_SCIENCES,
# BIOMEDICAL_SCIENCES,
# BIOSTATISTICS,
# BUSINESS_ADMINISTRATION,
# BUSINESS_ANALYTICS,
# CARDIOVASCULAR_TECHNOLOGY,
# CHEMISTRY,
# CHINESE_STUDIES,
# CLASSICS,
# COMMUNICATION_SCIENCES_AND_DISORDERS,
# COMPARATIVE_LITERATURE,
# COMPUTER_SCIENCE_/_COMPUTER_ENGINEERING,
# COUNSELING_/_COUNSELOR_EDUCATION,
# CREATIVE_WRITING,
# CRIMINOLOGY_AND_CRIMINAL_JUSTICE,
# CYBER_INTELLIGENCE,
# DANCE,
# ECONOMICS,
# EDUCATION:_EARLY_CHILDHOOD_EDUCATION,
# EDUCATION:_ELEMENTARY_EDUCATION,
# EDUCATION:_LANGUAGE_AND_LITERACY,
# EDUCATION:_LEARNING_DESIGN_AND_TECHNOLOGIES,
# EDUCATION:_MIDDLE_LEVEL_EDUCATION,
# EDUCATION:_PHYSICAL_EDUCATION,
# EDUCATION:_SECONDARY_EDUCATION,
# EDUCATION:_SPECIAL_EDUCATION,
# EDUCATION:_TEACHER_EDUCATION,
# EDUCATIONAL_ADMINISTRATION_AND_HIGHER_EDUCATION,
# ...
